# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

import histlite as hl
import csky as cy
import pandas as pd

from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.time import Time
from scipy import stats
#making healpy maps
import h5py as h5
import healpy as hp
import os

#import imp
#imp.reload(setup)

# %%
import setup
import chime_localizations as loc
# Out:
# Setting up Analysis for:
# GFU_for_2011_2012_2013_2014_2015_2016_2017_2018_2019
# Setting up GFU_for_2011_2012_2013_2014_2015_2016_2017_2018_2019...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2011_MC.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2011_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2012_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2013_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2014_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2015_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2016_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2017_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2018_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/IC86_2019_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2011_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2012_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2013_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2014_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2015_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2016_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2017_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2018_data.npy ...
# Reading /data/ana/analyses/gfu/version-002-p06/GRL/IC86_2019_data.npy ...
# Energy PDF Ratio Model...
#   * gamma = 4.0000 ...
# Signal Acceptance Model...
#   * gamma = 4.0000 ...
# Done.

# %%
mpl.rcParams['font.size'] = 20
ana=cy.CONF['ana']

seed=1
new_nside=512

# %%
frbs=setup.load_frbs(spatial_priors=True)
#spatial prior: use FRB20190416A, dec=33.3
wn=np.where(frbs['src']=='FRB20190416A')
wn=wn[0][0] #want only one of the bursts

frb_probs, msk=loc.make_healpix_map('FRB20190416A', new_nside=new_nside, max_cl=0.9997)
# Out:
# sum of map probabilities: 1.00000

# %%
src=setup.sources(84600., frbs['mjd'].values[wn], frbs['ra_deg'].values[wn], 
                  frbs['dec_deg'].values[wn])

##sp_tr used for getting llh prior, injecting events
sp_tr = cy.get_spatial_prior_trial_runner(src_tr=src, 
                        llh_priors=frb_probs, get_pixmask=True)

# %%
##inj signal w sp_tr
nsig=1
sig_trial= sp_tr.get_one_trial(nsig, seed=seed)

#del sig_trial.evss[0][0]['energy']
#sig_trial

# %%
## scan sky, w/in 99.97% CL only - pixmask call
sstr = cy.get_sky_scan_trial_runner(ana=ana, nside=new_nside, 
            src_kw={'mjd':src['mjd'], 't_100':src['t_100'], 'sigma_t':0.}, 
            pixmask=msk)

#%time scan = sstr.get_one_scan(seed = seed, mp_cpus=15, logging=True)

##if signal trial: 
# %time scan = sstr.get_one_scan_from_trial(sig_trial, seed = seed, mp_cpus=15, logging=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# /mnt/lfs7/user/jthwaites/csky/csky/trial.py in get_one_scan_from_trial(self, trial, logging, mp_cpus, mask, **fitter_args)
#    1034             scan_ra, scan_dec, trial[:2],
#    1035             min_dec=self.min_dec, max_dec=self.max_dec, mask=mask,
# -> 1036             logging=logging, **fitter_args)[-1]
#    1037         if self.ts_to_p:
#    1038             mlog10p = -np.log10(self.ts_to_p(scan_dec, scan[0]))
#
# /mnt/lfs7/user/jthwaites/csky/csky/trial.py in get_one_scan_from_trial(self, scan_ra, scan_dec, evss_ns_excluded_tuple, min_dec, max_dec, cut_n_sigma, mask, mp_cpus, logging, **fitter_args)
#    1981             for ev_list in evss:
#    1982                 for evs in ev_list:
# -> 1983                     all_evs += evs
#    1984             if( len(all_evs)<100 ): # todo: set max N_evss as function parameter
#    1985                 delta_angle_pix_evss = coord.delta_angle(
#
# /mnt/lfs7/user/jthwaites/csky/csky/utils.py in __add__(self, other)
#     249
#     250     def __add__(self, other):
# --> 251         assert sorted(self._dict) == sorted(other._dict)
#     252         init = {}
#     253         for k in sorted(self._dict):
#
# AssertionError:

# %%
#if len(np.where(scan[1]>0.)[0])==0: max_map=2. 
#else: max_map=max(scan[1])
#hp.mollview(scan[1], coord='C',rot=180, min=0., max=max_map)

# %%
ts_range=[min(sp_tr.llh_prior_term[0]),max(scan[1])]
setup.plot_zoom(scan[1], src['ra'][0], src['dec'][0], contour_scan=False, 
                title='TS, without prior',
                reso=2., col_label=r"TS", cmap='viridis')

# %%
setup.plot_zoom(sp_tr.llh_prior_term[0], src['ra'][0], src['dec'][0], contour_scan=False, 
                title='Prior Only, CL<99.97%', 
                reso=2., col_label=r"TS", cmap='Blues')

# %%
#make ts_with_prior >=0
ts_with_prior=np.zeros(len(scan[1]))
w=np.where(scan[1]>0.)[0]
for i in w:
    pixel_ts=scan[1][i] + sp_tr.llh_prior_term[0][i]
    ts_with_prior[i]=max([pixel_ts,0])
    
#ts_with_prior = scan[1] + sp_tr.llh_prior_term[0]

# %%
setup.plot_zoom(ts_with_prior, src['ra'][0], src['dec'][0], contour_scan=False, 
                title='TS, with prior', 
                reso=1., col_label=r"TS", cmap='viridis')
